# %%
import pandas as pd
import random
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
from sklearn import datasets, linear_model


df=pd.read_csv("C:/Users/anilp/Project_Files/EDA.csv", skiprows=1)

print(df.head())
df.shape
# Out:
#    4.000000
# 0  0.000000
# 1  0.026905
# 2  0.026905
# 3  0.030748
# 4  0.030748
# (35490, 1)

# %%
eda_value = df['4.000000']
eda_value.describe()
# Out:
# count    35490.000000
# mean         3.321324
# std          2.974339
# min          0.000000
# 25%          0.275453
# 50%          3.638652
# 75%          6.276728
# max         11.585902
# Name: 4.000000, dtype: float64

# %%
sns.scatterplot(data=eda_value, marker='X')
# Out:
# <Axes: ylabel='4.000000'>

# %%
locations = eda_value[eda_value==0.0]
new_eda = eda_value.drop(locations)

correlation = np.corrcoef(eda_value)
correlation
# Out:
# 1.0
